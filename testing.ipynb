# %%
from data_loader import load_data_from_file
import json

# %%
from config import PAGE_CONFIGS, data_folder

# %%
import config

# %%
data_folder
# Out:
# 'data'

# %%
PAGE_CONFIGS['198722103478014']['token']
# Out:
# 'EAAK20sBW9vEBPXvayIJDXR38CdEquT3vw7NQJHaAlC9YAejhi5ZAZAz8oYZBrhoC6dZCYfaE1nCbY6BuVhIFVeBmLOcnZAZBKV9jAULMsFBrlTR1aBiHjC3hRFrQhMcmkeCDx6F62qaZC1Lw8vfZBJ23HdlhWVkxeI8ZCsVv6ikdSSqCNl6ZAOgmJE6bb19chpP4lBkYYLliG4bgZDZD'

# %%
PAGE_ACCESS_TOKEN = ""
for page_id in PAGE_CONFIGS.keys():
    PAGE_ACCESS_TOKEN = PAGE_CONFIGS[page_id]['token']

# %%
PAGE_ACCESS_TOKEN
# Out:
# 'EAAK20sBW9vEBPXvayIJDXR38CdEquT3vw7NQJHaAlC9YAejhi5ZAZAz8oYZBrhoC6dZCYfaE1nCbY6BuVhIFVeBmLOcnZAZBKV9jAULMsFBrlTR1aBiHjC3hRFrQhMcmkeCDx6F62qaZC1Lw8vfZBJ23HdlhWVkxeI8ZCsVv6ikdSSqCNl6ZAOgmJE6bb19chpP4lBkYYLliG4bgZDZD'
